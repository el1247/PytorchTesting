# %% [markdown]
# # Pytorch Test Youtube Model Understanding
# Notebook for following along with Pytorch model understand with CAPTUM, using [Pytorch](https://pytorch.org/tutorials/beginner/introyt/captumyt.html) website tutorial. This notebook will be similar to the previous Pytorch Test notebooks, as the [youtube content](https://www.youtube.com/watch?v=Am2EF9CLu-g) covers similiar works.

# %% [markdown]
# ### Choices for data

# %% [markdown]
# <br>

# %% [markdown]
# ### Libaries and Modules
# Importing the necessary libaries and modules for the notebook.

# %%
#Import cell
import captum
import json
import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import math
import numpy as np
import os, sys
import pandas as pd
import pickle as pk
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms

from captum.attr import IntegratedGradients, Occlusion, LayerGradCam, LayerAttribution
from captum.attr import visualization as viz
from datetime import datetime
from matplotlib.colors import LinearSegmentedColormap
from PIL import Image
from torch.utils.tensorboard import SummaryWriter

print("Imports complete")
# Out:
# Imports complete

# %% [markdown]
# <br>

# %% [markdown]
# ### Importing and preparing data sets
# Importing and preparing the data for the models.

# %%
#Gather datasets and prepare them for consumption

# %%
#Importing data sets

print("Data sets successfully imported.")
# Out:
# Data sets successfully imported.

# %%
#Loader definitions

print("Loaders defined.")
# Out:
# Loaders defined.

# %%
#Setting seed value
torch.manual_seed(1247)

# %% [markdown]
# <br>

# %% [markdown]
# ### Class Definitions
# <b>Classes:</b><br>
# <ul>
#     <li></li>
# </ul>

# %%
#Class definition cell

print("Classes defined.")
# Out:
# Classes defined.

# %% [markdown]
# <br>

# %% [markdown]
# ### Calculation functions
# <b>Functions:</b><br>
# <ul>
#     <li></li>
# </ul>

# %%
#Calculation functions cell

print("Calculation functions defined.")
# Out:
# Calculation functions defined.

# %% [markdown]
# <br>

# %% [markdown]
# ### Plotting functions
# <b>Functions:</b>
# <ul>
#     <li></li>
# </ul>

# %%
#Plotting functions Cell

print("Plotting functions defined.")
# Out:
# Plotting functions defined.

# %% [markdown]
# <br>

# %% [markdown]
# ### Main code
# Using Captum, the model can be interpretted in terms of attributions. There are 3 kinds available in Captum:
# <ul>
#     <li>Feature Attribution seeks to explain a particular output in terms of features of the input that generated it.</li>
#     <li>Layer Attribution examins the activity of a models hiddne layer subsequent to a particular input.</li>
#     <li>Neuron Attribution is analagous to layer attribution, but focusses on the activity of a single neuron.</li>
# </ul>

# %% [markdown]
# #### First Example

# %%
#Model creation
model = models.resnet101(weights='ResNet101_Weights.DEFAULT')
model = model.eval()

# %%
test_img = Image.open('data/testing/cat.jpg')
test_img_data = np.asarray(test_img)
plt.imshow(test_img_data)
plt.show()

# %%
#Transformation definitions
transform = transforms.Compose([
    transforms.Resize(224),
    transforms.CenterCrop(224),
    transforms.ToTensor()])

transform_normalize = transforms.Normalize(
    mean=[0.485, 0.456, 0.406],
    std=[0.229, 0.224, 0.225])

# %%
transformed_img = transform(test_img)
input_img = transform_normalize(transformed_img)
intput_img = input_img.unsqueeze(0) #model requires a dummy batch dimension

labels_path = 'img/imagenet_class_index.json'
with open(labels_path) as json_data:
    idx_to_labels = json.load(json_data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1232/1136403139.py in <module>
#       4
#       5 labels_path = 'img/imagenet_class_index.json'
# ----> 6 with open(labels_path) as json_data:
#       7     idx_to_labels = json.load(json_data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'img/imagenet_class_index.json'

# %% [markdown]
# There was an error downloading the files, as they are only macOS suitable. A workaround will be investigated.

# %% [markdown]
# <br>
